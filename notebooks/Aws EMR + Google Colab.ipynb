# %% [markdown]
# <a href="https://colab.research.google.com/github/msilvadev/data-science/blob/main/Aws%20EMR%20%2B%20Google%20Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Install the Scala Kernel
# If you get a "scala" kernel not recognized warning when loading up the notebook for the first time, start by running the two cells below. Once you are done **reload the page** to load the notebook in the installed Scala kernel.

# %%
! pip install --upgrade setuptools
# Out:
# ...
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %%
# %%bash
# sudo apt-get install libkrb5-dev
# sudo apt install python3-wheel
#
# # Run below commands in google colab# install Java8
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
#
# # download spark3.0.0
# !wget -q http://apache.osuosl.org/spark/spark-3.0.0/spark-3.0.0-bin-hadoop3.2.tgz
#
# # unzip it
# !tar xf spark-3.0.0-bin-hadoop3.2.tgz# install findspark
# !pip install -q findspark
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# libkrb5-dev is already the newest version (1.16-2ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# python3-wheel is already the newest version (0.30.0-0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# bash: line 5: !apt-get: command not found
# bash: line 8: !wget: command not found
# bash: line 11: !tar: command not found
# bash: line 12: !pip: command not found

# %%
! pip3 install sparkmagic
# Out:
# ...
#   Using cached sparkmagic-0.18.0-py3-none-any.whl
# ...
#   Using cached requests_kerberos-0.12.0-py2.py3-none-any.whl (14 kB)
# ...
#   Using cached pykerberos-1.2.1.tar.gz (24 kB)
# ...
#   Created wheel for pykerberos: filename=pykerberos-1.2.1-cp37-cp37m-linux_x86_64.whl size=71556 sha256=7700f7f63f968e7a5e5cf100dc168240d0a483ea68f8c1abe79d74f768f44f5a
#   Stored in directory: /root/.cache/pip/wheels/49/70/e2/33a356bfc619e7cfa71c2a14f6fb976c0963d1bfa02e885151
# Successfully built pykerberos
# ...
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-97be79807d8b> in <module>()
# ----> 1 java -version
#
# NameError: name 'java' is not defined

# %%
# %load_ext sparkmagic.magics
# %manage_spark
# Out:
# MagicsControllerWidget(children=(Tab(children=(ManageSessionWidget(children=(HTML(value='<br/>'), HTML(value='…

# %%
import org.apache.spark

# %% [markdown]
# # New Section
